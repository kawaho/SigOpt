# %%
from IPython.display import Image, display
import time
display(Image(filename='./ggHcat0_160_ggH_gaus.png', width=500))

# %%
from IPython.display import Image, display
import time
display(Image(filename='./ggHcat0_150_ggH_gaus.png', width=500))
